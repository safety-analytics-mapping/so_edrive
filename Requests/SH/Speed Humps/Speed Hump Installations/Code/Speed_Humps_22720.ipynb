# %%
from ris import pysqldb
from IPython.display import clear_output
from collections import defaultdict
from collections import defaultdict, namedtuple
import datetime 
import pandas as pd
import numpy as np
import os
from sqlalchemy import create_engine

clear_output()
timestamp = datetime.datetime.now().strftime('%Y-%m-%d_%H:%M')
ts = datetime.datetime.now().strftime('%Y-%m-%d')

print 'Notebook run: {}'.format(timestamp)
print os.getcwd()
# Out:
# Notebook run: 2020-02-28_17:18
# E:\RIS\Staff Folders\Samuel\Requests\SH\Speed Humps

# %%
#Database connection
cdb = pysqldb.DbConnect(server='DOTDEVRHPGSQL01', database='CRASHDATA', type='PG')
# Out:
# Additional database connection details required:
# User name (crashdata):soge
# Password (crashdata)········
# Database connection (PG) to CRASHDATA on DOTDEVRHPGSQL01 - user: soge
# Connection established 2020-02-28 17:18:57

# %%
cdb.connect()
# Out:
# Database connection (PG) to CRASHDATA on DOTDEVRHPGSQL01 - user: soge
# Connection established 2020-02-28 17:35:08

# %%
cdb.shp_to_table(path=r'E:\RIS\Staff Folders\Samuel\Requests\SH\Speed Humps\Installations_2018toJan2020',shp_name='Installations_2018toJan2020.shp',schema='working', table_name = 'Installations_2018toJan2020',  overwrite=True)
# Out:
# Query run in 24000 microseconds
# Failure:
#
# - Query run 2020-02-28 17:25:02.245000
# 	comment on table working."installations_2018tojan2020" is 'installations_2018tojan2020 created by soge on 2020-02-28 17:25
#         - imported using pysql module -'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
cdb.csv_to_table(input_file=r'E:\RIS\Staff Folders\Samuel\Requests\SH\Speed Humps\Installations_2018toJan2020_.csv',schema='working', overwrite=True)
# Out:
# Bulk loading data...
# Failure:
#
# - Query run 2020-02-28 17:35:11.844000
# 	ALTER TABLE working.stg__soge_202002281735 DROP COLUMN IF EXISTS ogc_fid
# Database connection (PG) to CRASHDATA on DOTDEVRHPGSQL01 - user: soge
# Connection closed 2020-02-28 17:35:11
# Database connection (PG) to CRASHDATA on DOTDEVRHPGSQL01 - user: soge
# Connection established 2020-02-28 17:35:11
# Failure:
#
# - Query run 2020-02-28 17:35:11.905000
# 	select  * from working.stg__soge_202002281735 LIMIT 1
# Database connection (PG) to CRASHDATA on DOTDEVRHPGSQL01 - user: soge
# Connection closed 2020-02-28 17:35:11
# Database connection (PG) to CRASHDATA on DOTDEVRHPGSQL01 - user: soge
# Connection established 2020-02-28 17:35:11
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-1d833de30521> in <module>()
# ...

# %%
def df_to_sql(df,tbl_name,db): 
    
    """ (df,tbl,name) """
    
    engine = create_engine('postgresql://{user}:{pw}@10.243.154.88:5432/CRASHDATA'.format(user=db.params['user'],
                                                                                          pw=db.params['password']),
                                                                                          echo=False)
    
    df.to_sql(name='{}'.format(tbl_name), con= engine, if_exists = 'replace', index=False, schema = 'working')
    
    #db.query("""ALTER TABLE {tbl}
    #            ALTER COLUMN geom TYPE Geometry USING geom::Geometry;
                
    #            grant all on {tbl} to public;""".format(tbl=tbl_name))
    
    return tbl_name

# %%
x=pd.read_csv('E:\RIS\Staff Folders\Samuel\Requests\SH\Speed Humps\Installations_2018toJan2020_.csv')

# %%
x
# Out:
#                                      STREET_1               STREET_2  \
# 0                             EAST 107 STREET               AVENUE J
# 1                             EAST 107 STREET               AVENUE J
# 2                             EAST 107 STREET               AVENUE J
# 3                              MIDWOOD STREET        KINGSTON AVENUE
# 4                               OCEAN PARKWAY               AVENUE T
# 5                              MIDWOOD STREET        KINGSTON AVENUE
# 6                               ARTHUR AVENUE        EAST 179 STREET
# 7                               MARTHA AVENUE        EAST 238 STREET
# 8                             ST PAULS AVENUE          PAXTON STREET
# 9                             ST PAULS AVENUE          PAXTON STREET
# 10                            ST PAULS AVENUE          PAXTON STREET
# 11                            ST PAULS AVENUE          PAXTON STREET
# 12                            ST PAULS AVENUE            SWAN STREET
# ...

# %%
df_to_sql(x,'Installations_2018toJan2020',cdb)
# Out:
# 'Installations_2018toJan2020'
