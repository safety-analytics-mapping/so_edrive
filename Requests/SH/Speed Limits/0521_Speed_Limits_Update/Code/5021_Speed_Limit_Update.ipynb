# %% [markdown]
# # Default Import

# %%
from ris import pysqldb
from IPython.display import Markdown, clear_output
from sqlalchemy import create_engine
import ris
import getpass
import datetime 
import pandas as pd
import numpy as np
import os
import requests

timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M')
ts = datetime.datetime.now().strftime('%Y-%m-%d')

Markdown('<strong>Notebook run on: {} | by {} | Using ris library version: {} | File Location: {}'.format(
    timestamp, getpass.getuser(), ris.__version__, os.getcwd()
))
# Out:
# <strong>Notebook run on: 2021-05-26 17:41 | by soge | Using ris library version: 2.2.1 | File Location: E:\RIS\Staff Folders\Samuel\Requests\SH\Speed Limits\0521_Speed_Limits_Update

# %% [markdown]
# # Db connections

# %%
try: 
    db.params['user']
except:
    db = pysqldb.DbConnect(type='PG', server='dotdevrhpgsql01', database='CRASHDATA')

# %%
#sip = pysqldb.DbConnect(server='dotpgsql01', database='sip', type='PG', user = db.params['user'], password = db.params['password'])
#forms = pysqldb.DbConnect(server='dot55sql01', database='forms', type='MS', user = 'arcgis', password = 'arcgis')

# %% [markdown]
# #BACK UP SPEED LIMITS FILE
# #CREATE A TABLE WITH SPEED LIMITS DATA AND TODAY'S DATE
# #i.e Archive Copy

# %%
db.query("""
CREATE TABLE archive_speed_limit_19d_30521 AS

SELECT * FROM speed_limit_19d;

GRANT ALL ON archive_speed_limit_19d_30521 TO PUBLIC;
""")
# Out:
# - Query run 2021-03-05 13:09:49.292000
#  Query time: Query run in 197000 microseconds
#  * Returned 0 rows *

# %% [markdown]
# Streets:
#
# Milford Avenue from Ocean Terrace to Clove Road

# %%
pelham_pkwy = map(int,list(pd.read_excel('pelham_pkwy.xlsx').segmentid))
throgsneck= map(int,list(pd.read_excel('throgsneck.xlsx').segmentid))
jerome= map(int,list(pd.read_excel('jerome.xlsx').segmentid))
woodhaven= map(int,list(pd.read_excel('woodhaven.xlsx').segmentid))
crossbay= map(int,list(pd.read_excel('crossbay.xlsx').segmentid))
astoria= map(int,list(pd.read_excel('astoria.xlsx').segmentid))
south_conduit= map(int,list(pd.read_excel('south_conduit.xlsx').segmentid))
north_conduit= map(int,list(pd.read_excel('north_conduit.xlsx').segmentid))
hylan= map(int,list(pd.read_excel('hylan.xlsx').segmentid))
van_wyck= map(int,list(pd.read_excel('van_wyck.xlsx').segmentid))

# %%
total = tuple(pelham_pkwy + throgsneck + jerome + woodhaven + crossbay + astoria + south_conduit + north_conduit + hylan + van_wyck)

# %% [markdown]
# ### Inserting into Speed limits table if necessary

# %% [markdown]
# insert = db.dfquery("""
# INSERT INTO speed_limit_19d(segmentid, street, postvz_sl, postvz_sg, prevz_sl, prevz_sg, version, geom)
# SELECT segmentid::int , street, 0 postvz_sl, 'NO'::varchar postvz_sg, 0 prevz_sl, 'NO'::varchar _prevz_sg, '19d' "version", geom
# FROM LION
# WHERE segmentid ::int IN  ('0312733', '0312802', '0312769')
# """)

# %%
x = db.dfquery("""
SELECT segmentid, street, postvz_sl, postvz_sg, prevz_sl, prevz_sg, 
       version, geom
FROM public.speed_limit_20d
WHERE segmentid ::int IN  {} p
""".format(total))
# Out:
# - Query failed: syntax error at or near "p"
# LINE 5: ...7, 170491, 234851, 234852, 311063, 311069, 311134, 311135) p
#                                                                       ^
#
#
# - Query run 2021-05-26 17:42:14.843000
#
# SELECT segmentid, street, postvz_sl, postvz_sg, prevz_sl, prevz_sg,
#        version, geom
# FROM public.speed_limit_20d
# ...

# %%
#segs = tuple(map(int,list(x.segmentid)))
segs = tuple(map(int,segments))

# %%
y = db.query("""UPDATE public.speed_limit_19d
                SET postvz_sl = 30
                WHERE segmentid in {}
                """.format(segs))
# Out:
# - Query run 2021-03-05 13:16:50.353000
#  Query time: Query run in 52000 microseconds
#  * Returned 0 rows *

# %%
sl_update= tuple(['299580', '299583', '299575', '299578', '299587', '299588', '299585', '299586', '311967', '311968', '311961', '311962', '9008829', '9008830', '9008825', '9008826', '302883', '302884', '302874', '302875', '302972', '302973', '302960', '302961', '68148', '68153', '68145', '68146', '68161', '68163', '68157', '68160', '67930', '68030', '67925', '67928', '68037', '68045', '68033', '68035', '68558', '68613', '68548', '68554', '68666', '68719', '68627', '68664', '68288', '68289', '68280', '68282', '68303', '68305', '68293', '68302', '75686', '75687', '75677', '75679', '75853', '75856', '75691', '75852', '75496', '75506', '68723', '68736', '75532', '75536', '75512', '75521', '76150', '76154', '76147', '76149', '76166', '134035', '76160', '76163', '76012', '76013', '76003', '76009', '76142', '76144', '76017', '76140', '145368', '145369', '145366', '145367', '145372', '145373', '145370', '145371', '145306', '145315', '145304', '145305', '145364', '145365', '145361', '145363', '178504', '178565', '178460', '178461', '183742', '184899', '178566', '178567', '160778', '160783', '160573', '160777', '169373', '176786', '160784', '169371', '186401', '188426', '186338', '186339', '188488', '188650', '188427', '188487', '185003', '185004', '184900', '185002', '185836', '185839', '185832', '185835', '194046', '194052', '193981', '194042', '194237', '194238', '194053', '194054', '193924', '193966', '191120', '191121', '193978', '193979', '193969', '193976', '219231', '219232', '215271', '219202', '231427', '238955', '229444', '231426', '195120', '195121', '194257', '195119', '196626', '215270', '195122', '196622', '262073', '262074', '253897', '253898', '275643', '275644', '262076', '262077', '247713', '247714', '238956', '247712', '253892', '253893', '247716', '247717', '281758', '281760', '279646', '279647', '281767', '282023', '281764', '281765', '279631', '279632', '275645', '275646', '279643', '279644', '279637', '279638', '287219', '287220', '287125', '287216', '287226', '287227', '287221', '287222', '282041', '282045', '282036', '282037', '287121', '287124', '282046', '287120', '291771', '291772', '291768', '291769', '292612', '292613', '292610', '292611', '288644', '288645', '288642', '288643', '289601', '289602', '289596', '289597', '156001', '156005', '155987', '155988', '156037', '156038', '156012', '156018', '155901', '155916', '155882', '155900', '155984', '155986', '155977', '155979', '156136', '156159', '156133', '156134', '156190', '156200', '156160', '156163', '156060', '156066', '156053', '156055', '156121', '156122', '156077', '156102', '