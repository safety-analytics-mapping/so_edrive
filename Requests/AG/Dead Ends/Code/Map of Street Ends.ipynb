# %% [markdown]
# ## Request:  Map of Street Ends
#
# ### 1. Locating all of the dead ends on LION

# %%
from ris import db2  #library designed for SQL database connection and querying
from IPython.display import clear_output
import datetime 
from datetime import date
import pandas as pd
import os
import decimal
from sqlalchemy import create_engine


clear_output()
timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M')
print 'Notebook run: {}'.format(timestamp)
print os.getcwd()
# %load_ext sql
# Out:
# Notebook run: 2019-07-16 17:11
# C:\Users\soge\Desktop

# %%
#Database connections
#db = db2.PostgresDb('dotdevpgsql02', 'GISGRID', quiet = True)
cdb = db2.PostgresDb('dotdevpgsql02', 'CRASHDATA', quiet = True)
# Out:
# User name (CRASHDATA):soge
# Password (CRASHDATA)········

# %%
##

# %%
nfrom =  cdb.query("""--nodes1
                        select distinct n.nodeid,l.geom 
                        from node n
                        join lion l on
                        n.nodeid = l.nodeidfrom::int
                        --where nodeid = 25438
                        and l.rb_layer in ('R', 'B', 'N') and l.featuretyp not in ('1', '2', '3', '7', 'A', 'F')
                        and n.vintersect is null""")

# %%
nfrom = pd.DataFrame(nfrom.data, columns =['nodeid','geom'])

# %%
nfrom
# Out:
#          nodeid                                               geom
# 0            10  0105000020D70800000100000001020000000200000000...
# 1            10  0105000020D70800000100000001020000000200000000...
# 2            11  0105000020D70800000100000001020000000200000000...
# 3            11  0105000020D70800000100000001020000000200000000...
# 4            14  0105000020D70800000100000001020000000200000000...
# 5            17  0105000020D70800000100000001020000000400000080...
# 6            18  0105000020D70800000100000001020000000200000080...
# 7            18  0105000020D70800000100000001020000000200000080...
# 8            19  0105000020D70800000100000001020000000200000000...
# 9            19  0105000020D70800000100000001020000000200000000...
# 10           22  0105000020D70800000100000001020000000200000080...
# 11           23  0105000020D70800000100000001020000000200000000...
# 12           23  0105000020D70800000100000001020000000200000000...
# ...

# %%
nto =  cdb.query("""--nodes1
                        select distinct n.nodeid,l.geom 
                        from node n
                        join lion l on
                        n.nodeid = l.nodeidto::int
                        --where nodeid = 25438
                        and l.rb_layer in ('R', 'B', 'N') and l.featuretyp not in ('1', '2', '3', '7', 'A', 'F')
                        and n.vintersect is null""")

# %%
nto = pd.DataFrame(nto.data, columns =['nodeid','geom'])

# %%
nto
# Out:
#          nodeid                                               geom
# 0             9  0105000020D70800000100000001020000000200000000...
# 1            10  0105000020D70800000100000001020000000200000000...
# 2            11  0105000020D70800000100000001020000000200000080...
# 3            13  0105000020D70800000100000001020000000200000080...
# 4            14  0105000020D70800000100000001020000000200000080...
# 5            14  0105000020D70800000100000001020000000200000000...
# 6            16  0105000020D70800000100000001020000000200000000...
# 7            17  0105000020D70800000100000001020000000300000000...
# 8            18  0105000020D70800000100000001020000000200000080...
# 9            18  0105000020D70800000100000001020000000200000080...
# 10           19  0105000020D70800000100000001020000000200000000...
# 11           21  0105000020D70800000100000001020000000200000000...
# 12           22  0105000020D70800000100000001020000000200000000...
# ...

# %%
nodes = db2.query_to_table(cdb,"""select nodeid,geom from node""")

# %%
nodes
# Out:
#          nodeid                                               geom
# 0       9008720  0101000020D70800008021867E01D92E41006ED2DF9B72...
# 1       9008722  0101000020D708000000BDD0EA39EC2E4100D2A79B60D9...
# 2       9008727  0101000020D7080000001A538AD1002F4100B861E59152...
# 3       9008728  0101000020D7080000803B9C60EAEB2E410002BD4741D3...
# 4       9008729  0101000020D708000000B24CEF62F52E41001687A0B104...
# 5       9008730  0101000020D708000080BBB3C178FD2E4100A0029A4C26...
# 6       9008734  0101000020D7080000807ECEFE464F2F41006AEE5F4E28...
# 7       9008742  0101000020D708000000C716C97C472F41006E6BC69B1B...
# 8       9008748  0101000020D708000000357ED1AFA52E41006270EA8BD7...
# 9       9008749  0101000020D708000000DC69301AA82E410006640B67EB...
# 10      9008754  0101000020D70800008064A644C4A82E4100EEF1122FEA...
# 11      9008755  0101000020D7080000009BB8AD7CC72E410072B5E607F8...
# 12      9008758  0101000020D708000000E23CB72CC92E410034ECFC237A...
# ...

# %%
b=pd.merge(nfrom.nodeid, nto.nodeid, how='inner')

# %%
b
# Out:
#          nodeid
# 0            10
# 1            10
# 2            11
# 3            11
# 4            14
# 5            14
# 6            17
# 7            18
# 8            18
# 9            18
# 10           18
# 11           19
# 12           19
# 13           22
# 14           22
# 15           23
# 16           23
# 17           23
# 18           24
# 19           25
# 20           25
# 21           26
# 22           26
# 23           27
# 24           27
# 25           31
# 26           37
# 27           37
# 28           42
# 29           42
# ...         ...
# 230574  9053394
# 230575  9053394
# 230576  9053395
# 230577  9053396
# 230578  9053397
# 230579  9053400
# 230580  9053400
# 230581  9053401
# 230582  9053402
# 230583  9053404
# 230584  9053404
# 230585  9053406
# 230586  9053406
# 230587  9053426
# 230588  9053426
# 230589  9053427
# 230590  9053429
# 230591  9053430
# 230592  9053430
# 230593  9053431
# 230594  9053432
# 230595  9053432
# 230596  9053433
# ...

# %%
c = set([ int(i) for i in set(b.nodeid)])

# %%
a= set([ int(i) for i in set(nodes.nodeid)])

# %%
d= a^c

# %%
d
# Out:
# {1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  9,
#  12,
#  13,
#  15,
#  16,
#  20,
#  21,
#  28,
#  30,
#  32,
#  33,
#  34,
#  36,
#  38,
#  39,
#  40,
#  43,
#  45,
#  58,
#  60,
#  61,
#  86,
#  88,
#  90,
#  91,
#  92,
#  100,
#  101,
#  103,
#  105,
#  106,
#  108,
#  109,
#  110,
#  111,
#  122,
#  134,
#  140,
#  143,
#  151,
#  152,
#  153,
#  154,
#  156,
#  157,
#  158,
#  159,
#  160,
#  162,
#  163,
#  164,
#  182,
#  187,
#  189,
#  202,
#  206,
#  207,
#  210,
#  35,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  220,
#  41,
#  252,
#  265,
#  268,
#  283,
#  284,
#  288,
#  289,
#  312,
#  318,
#  320,
#  324,
#  338,
#  342,
#  349,
#  355,
#  363,
#  366,
#  373,
#  378,
#  379,
#  381,
#  382,
#  384,
#  387,
#  392,
#  393,
#  397,
#  399,
#  87448,
#  402,
#  414,
#  421,
#  422,
#  425,
#  426,
#  427,
#  428,
#  429,
#  430,
#  432,
#  433,
#  434,
#  435,
#  436,
#  437,
#  438,
#  440,
#  441,
#  442,
#  444,
#  451,
#  454,
#  459,
#  466,
# ...

# %%
ends=pd.DataFrame(map(decimal.Decimal, d),columns=['nodeid'])

# %%
len(ends)
# Out:
# 27988

# %%
result = pd.concat([nodes, ends], axis=1, join='inner')

# %%
dead_ends = ends.merge(nodes)

# %%
dead_ends
# Out:
#         nodeid                                               geom
# 0            1  0101000020D708000000DF7ED2F5DA2B4100305CDC4227...
# 1            2  0101000020D708000080E9169A49F62B4100FC80101AFC...
# 2            3  0101000020D7080000809C49233ED72B41007847B54969...
# 3            4  0101000020D70800008052A42648D72B410034F61E45EA...
# 4            5  0101000020D7080000009629F3DCD72B41000458FC4365...
# 5            6  0101000020D708000000B28FB296D82B4100881D2D6476...
# 6            7  0101000020D70800008047B11F00D92B4100E8B2D90C5E...
# 7            8  0101000020D70800008082C6B314E12B410084C42624DD...
# 8            9  0101000020D708000000E967DE59E12B4100748C2FD0E1...
# 9           12  0101000020D708000080D2AB52AADE2B410088E5783422...
# 10          13  0101000020D708000000070992E7E02B410000B1157125...
# 11          15  0101000020D7080000001F7719DEE12B41005C72AF3D17...
# 12          16  0101000020D7080000007B548068E12B4100DC0CAEB630...
# ...

# %%
engine = create_engine('postgresql://{user}:{pw}@10.243.154.52:5432/CRASHDATA'.format(user=cdb.params['user'],
                                                                                          pw=cdb.params['password']),
                                                                                          echo=False)

dead_ends.to_sql(name='dead_ends', con= engine, if_exists = 'replace', index=False)

# %%
cdb.query("""ALTER TABLE dead_ends
                ALTER COLUMN geom TYPE Geometry USING geom::Geometry;
                
                grant all on dead_ends to public;""")
# Out:
# output(data=None, columns=None, desc=None)

# %%
nodes = db2.query_to_table(cdb,"""select nodeid,geom 
                                  from node 
                                  where nodeid in  (""" format(""",""".join(str(d) for node in d) """)
# Out:
# 27988

# %%
#for i in d:
#    print nodes.loc[nodes.nodeid==decimal.Decimal(i)]

# %%
#print nodes.loc[nodes.nodeid==decimal.Decimal(2788)]

# %%
e=pd.DataFrame(d)

# %%
test = db2.query_to_table(cdb,"""select nodeidfrom
                    from lion
                    where rb_layer in ('R', 'B', 'N') and featuretyp not in ('1', '2', '3', '7', 'A', 'F')
                    and nodeidfrom not in (select nodeidto
                    from lion
                        where rb_layer in ('R', 'B', 'N') and featuretyp not in ('1', '2', '3', '7', 'A', 'F')
                        ) 
                 """ )
# Out:
# Query Failed:
#
# 	select nodeidfrom
# 	                    from lion
# 	                    where rb_layer in ('R', 'B', 'N') and featuretyp not in ('1', '2', '3', '7', 'A', 'F')
# 	                    and nodeidfrom not in (select nodeidto
# 	                    from lion
# 	                        where rb_layer in ('R', 'B', 'N') and featuretyp not in ('1', '2', '3', '7', 'A', 'F')
# 	                        )
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Python27\ArcGIS10.4\lib\site-packages\IPython\core\interactiveshell.py:2886: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
select tot.nodeid, n2.geom from (
select coalesce(nodeidto, nodeidfrom) nodeid from (
select distinct l.nodeidfrom
from lion l
join node n on
n.nodeid = l.nodeidfrom::int
where l.rb_layer in ('R', 'B', 'N') and l.featuretyp not in ('1', '2', '3', '7', 'A', 'F')
and n.vintersect is null
) f
full join
(
select distinct l.nodeidto
from lion l
join node n on
n.nodeid = l.nodeidto::int
where l.rb_layer in ('R', 'B', 'N') and l.featuretyp not in ('1', '2', '3', '7', 'A', 'F')
and n.vintersect is null
) t 
on f.nodeidfrom=t.nodeidto
where f.nodeidfrom is null or t.nodeidto is null) tot
join node n2
on tot.nodeid::int=n2.nodeid

# %%
select tot.nodeid, n2.geom from (
	select coalesce(nodeidto, nodeidfrom) nodeid from ( 
		select distinct l.nodeidfrom --nodeidfrom table
		from lion l
		join node n on
		n.nodeid = l.nodeidfrom::int
		where l.rb_layer in ('R', 'B', 'N') and l.featuretyp not in ('1', '2', '3', '7', 'A', 'F')
		and n.vintersect is null
		and l.masteridfrom is not null
		and l.masteridto is not null
		) f
		full join
		(
		select distinct l.nodeidto --nodeidto table
		from lion l
		join node n on
		n.nodeid = l.nodeidto::int
		where l.rb_layer in ('R', 'B', 'N') and l.featuretyp not in ('1', '2', '3', '7', 'A', 'F')
		and n.vintersect is null
		and l.masteridfrom is not null
		and l.masteridto is not null
		) t 
	on f.nodeidfrom=t.nodeidto
	where f.nodeidfrom is null or t.nodeidto is null) tot
join node n2
on tot.nodeid::int=n2.nodeid

# %%
from sqlalchemy import create_engine
import pyodbc
import psycopg2

sdb = db2.SqlDb('DOT55SQL01', 'FORMS', user='arcgis', db_pass='arcgis') #Database Connection

engine = create_engine('mssql+pyodbc://{user}:{pw}@FORMS'.format(user='arcgis',pw='arcgis'), echo=False)

# %%
dead_ends.to_sql(name='dead_ends', con= engine, if_exists = 'replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-61-bfb3222c1f9b> in <module>()
# ----> 1 dead_ends.to_sql(name='dead_ends', con= engine, if_exists = 'replace', index=False)
#
# C:\Python27\ArcGIS10.4\lib\site-packages\pandas\core\generic.pyc in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# C:\Python27\ArcGIS10.4\lib\site-packages\pandas\io\sql.pyc in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...
