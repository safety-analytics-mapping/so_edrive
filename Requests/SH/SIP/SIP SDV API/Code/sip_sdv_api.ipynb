# %% [markdown]
# # Default Import

# %%
from ris import pysqldb
from IPython.display import Markdown, clear_output
from sqlalchemy import create_engine
import ris
import getpass
import datetime 
import pandas as pd
import numpy as np
import os
import requests
import json

timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M')
ts = datetime.datetime.now().strftime('%Y-%m-%d')

Markdown('<strong>Notebook run on: {} | by {} | Using ris library version: {} | File Location: {}'.format(
    timestamp, getpass.getuser(), ris.__version__, os.getcwd()
))
# Out:
# <strong>Notebook run on: 2020-09-18 11:26 | by soge | Using ris library version: 1.5.6 | File Location: E:\RIS\Staff Folders\Samuel\Requests\SH\SIP SDV API

# %% [markdown]
# # Db connections

# %%
try: 
    db.params['user']
except:
    db = pysqldb.DbConnect(type='PG', server='dotpgsql01', database='sip')
# Out:
# Additional database connection details required:
# User name (sip):
# Password (sip)········
# Database connection (PG) to sip on dotpgsql01 - user:
# Connection established 2020-09-18 11:26:32
#
# Additional database connection details required:
# User name (sip):
# Password (sip)········
#
# Additional database connection details required:
# User name (sip):
# Password (sip)········
#
# Additional database connection details required:
# User name (sip):soge
# Password (sip)········

# %%
_api_url = "http://dotdevgisiis02/SafetyViewer2/SafetyVwrServicesAPI/Api/"
_api_hdr = {'APIKEY': 'SDV2-DEV'};

# %%
#sip = pysqldb.DbConnect(server='dotpgsql01', database='sip', type='PG', user = db.params['user'], password = db.params['password'])
#forms = pysqldb.DbConnect(server='dot55sql01', database='forms', type='MS', user = 'arcgis', password = 'arcgis')

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")
print(response.status_code)
print(response.json())
# Out:
# 200
# {u'timestamp': 1600442833, u'message': u'success', u'iss_position': {u'latitude': u'15.3766', u'longitude': u'-176.3926'}}

# %%
print(response.json()['message'])
# Out:
# success

# %%
#json_response = response.json()
dictionary = json.dumps(response.json(), sort_keys = True, indent = 4)
print(dictionary)
# Out:
# {
#     "iss_position": {
#         "latitude": "15.3766",
#         "longitude": "-176.3926"
#     },
#     "message": "success",
#     "timestamp": 1600442833
# }

# %%
response = requests.get("http://dotdevgisiis02/SafetyViewer2/SafetyVwrServicesAPI/Api/Crash/GetCrashHistory")
print(response.status_code)
# Out:
# 405

# %%
#------------------------------------
# CrashHistory: New Request
#------------------------------------
def GetCrashHistory():	
    _req_id = 0;
    _url = _api_url + "Crash/GetCrashHistory";
    _data = {
            "req_id":0,
            "sip_id": "866",
            "prj_title": "Crash History Sample",
            "sel_type": "NODE",
            "nd_seg_ids": "18976",
            "from": "01/01/2013",
            "to": "12/31/2017",
            "usr_id": "Seth",
            "crashfilters": []
        }
    r = requests.post(_url, data=_data, headers=_api_hdr)
    if(r.ok):

        jData = json.loads(r.content)
        print("Output contains {0} properties".format(len(jData)))
        print("\n")
        _req_id = jData["req_id"]
        print("req_id: " + str(jData["req_id"]))
        for row in jData["crash_hist"]:
            for c in row:
                print (c + ":"  + str(row[c])) # + ": " + str(jData["crash_hist"][key]))
            print("------");
    else:
        print("Error\n")	
        print(r.reason + ', ' + r.text)

    return _req_id

# %%
GetCrashHistory()
# Out:
# Output contains 26 properties
#
#
# req_id: 6521
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34684356
# inj:1
# id:2
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Jan 27 2013  9:20AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:9
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-01-27
# crashid:346843562013
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34751394
# inj:1
# id:3
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Mar  3 2013 10:00AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:10
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-03-03
# crashid:347513942013
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34752965
# inj:1
# id:4
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Feb 15 2013 11:55PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:8
# segmentid:-1
# hr:23
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-02-15
# crashid:347529652013
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:21:00-24:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34929297
# inj:1
# id:5
# danger_cnt:None
# pd_act:
# severity:A
# fatal_hdr:None
# tme:May 20 2013  6:51AM
# ksi_tot:None
# st_x:997183
# ksi:1
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:6
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-05-20
# crashid:349292972013
# hdr:None
# a:1
# c:0
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:1
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34939778
# inj:1
# id:6
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Jun  5 2013  9:45AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:9
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-06-05
# crashid:349397782013
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:BI
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34969501
# inj:1
# id:7
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Jul  6 2013  2:20PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:5
# segmentid:-1
# hr:14
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-07-06
# crashid:349695012013
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:12:00-15:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:BI
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34974216
# inj:1
# id:8
# danger_cnt:None
# pd_act:
# severity:None
# fatal_hdr:None
# tme:Jul 25 2013 10:00PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:8
# segmentid:-1
# hr:22
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-07-25
# crashid:349742162013
# hdr:None
# a:0
# c:0
# b:0
# hr_txt:21:00-24:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:1
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:34974219
# inj:1
# id:9
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Jul 19 2013  6:40AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:6
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-07-19
# crashid:349742192013
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35186717
# inj:1
# id:10
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Dec 23 2013  6:35PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:7
# segmentid:-1
# hr:18
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2013
# ac_date:2013-12-23
# crashid:351867172013
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:18:00-21:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35335952
# inj:1
# id:11
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:May  9 2014  3:30PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:6
# segmentid:-1
# hr:15
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2014
# ac_date:2014-05-09
# crashid:353359522014
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:15:00-18:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35488015
# inj:3
# id:12
# danger_cnt:None
# pd_act:
# severity:CCC
# fatal_hdr:None
# tme:Sep 26 2014 10:11AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:10
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2014
# ac_date:2014-09-26
# crashid:354880152014
# hdr:None
# a:0
# c:3
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35531813
# inj:1
# id:13
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Oct  4 2014  8:25AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:8
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2014
# ac_date:2014-10-04
# crashid:355318132014
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35573759
# inj:2
# id:14
# danger_cnt:None
# pd_act:
# severity:CC
# fatal_hdr:None
# tme:Nov  3 2014  9:05PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:8
# segmentid:-1
# hr:21
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2014
# ac_date:2014-11-03
# crashid:355737592014
# hdr:None
# a:0
# c:2
# b:0
# hr_txt:21:00-24:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35593261
# inj:0
# id:15
# danger_cnt:None
# pd_act:
# severity:None
# fatal_hdr:None
# tme:Jul 18 2014  7:30PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:7
# segmentid:-1
# hr:19
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2014
# ac_date:2014-07-18
# crashid:355932612014
# hdr:None
# a:0
# c:0
# b:0
# hr_txt:18:00-21:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35643035
# inj:3
# id:16
# danger_cnt:None
# pd_act:
# severity:CCC
# fatal_hdr:None
# tme:Sep 10 2014  1:50PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:5
# segmentid:-1
# hr:13
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2014
# ac_date:2014-09-10
# crashid:356430352014
# hdr:None
# a:0
# c:3
# b:0
# hr_txt:12:00-15:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35699045
# inj:0
# id:17
# danger_cnt:None
# pd_act:
# severity:K
# fatal_hdr:None
# tme:Apr 18 2015 11:31AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:11
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2015
# ac_date:2015-04-18
# crashid:356990452015
# hdr:None
# a:0
# c:0
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35712846
# inj:1
# id:18
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Dec 26 2014  2:20PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:5
# segmentid:-1
# hr:14
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2014
# ac_date:2014-12-26
# crashid:357128462014
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:12:00-15:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35721526
# inj:1
# id:19
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Mar 22 2015  5:00PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:6
# segmentid:-1
# hr:17
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2015
# ac_date:2015-03-22
# crashid:357215262015
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:15:00-18:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35782571
# inj:2
# id:20
# danger_cnt:None
# pd_act:
# severity:CC
# fatal_hdr:None
# tme:May 19 2015  7:57AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:7
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2015
# ac_date:2015-05-19
# crashid:357825712015
# hdr:None
# a:0
# c:2
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35893402
# inj:1
# id:21
# danger_cnt:None
# pd_act:
# severity:B
# fatal_hdr:None
# tme:Jun 22 2015  3:10PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:6
# segmentid:-1
# hr:15
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2015
# ac_date:2015-06-22
# crashid:358934022015
# hdr:None
# a:0
# c:0
# b:1
# hr_txt:15:00-18:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:35923377
# inj:1
# id:22
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Sep 24 2015  9:15AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:9
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2015
# ac_date:2015-09-24
# crashid:359233772015
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36213199
# inj:1
# id:23
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Apr  2 2016  8:40AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:8
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-04-02
# crashid:362131992016
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:BI
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36236969
# inj:1
# id:24
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:May 24 2016  3:30PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:6
# segmentid:-1
# hr:15
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-05-24
# crashid:362369692016
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:15:00-18:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36301398
# inj:1
# id:25
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:May  9 2016  6:50AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:6
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-05-09
# crashid:363013982016
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36310096
# inj:1
# id:26
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Jun 28 2016  1:40AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:1
# segmentid:-1
# hr:1
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-06-28
# crashid:363100962016
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:00:00-03:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36359748
# inj:3
# id:27
# danger_cnt:None
# pd_act:
# severity:CCC
# fatal_hdr:None
# tme:Aug 21 2016  1:15PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:5
# segmentid:-1
# hr:13
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-08-21
# crashid:363597482016
# hdr:None
# a:0
# c:3
# b:0
# hr_txt:12:00-15:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36361946
# inj:1
# id:28
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Aug 25 2016  3:35PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:6
# segmentid:-1
# hr:15
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-08-25
# crashid:363619462016
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:15:00-18:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:BI
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36416109
# inj:1
# id:29
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Sep 13 2016  6:30AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:6
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-09-13
# crashid:364161092016
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36480609
# inj:0
# id:30
# danger_cnt:None
# pd_act:
# severity:None
# fatal_hdr:None
# tme:Nov 18 2016 11:00AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:11
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2016
# ac_date:2016-11-18
# crashid:364806092016
# hdr:None
# a:0
# c:0
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36570907
# inj:2
# id:31
# danger_cnt:None
# pd_act:
# severity:CC
# fatal_hdr:None
# tme:Jan 17 2017  7:50PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:7
# segmentid:-1
# hr:19
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-01-17
# crashid:365709072017
# hdr:None
# a:0
# c:2
# b:0
# hr_txt:18:00-21:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36741634
# inj:1
# id:32
# danger_cnt:None
# pd_act:
# severity:A
# fatal_hdr:None
# tme:May 25 2017  3:00PM
# ksi_tot:None
# st_x:997183
# ksi:1
# inj_per:None
# st_y:187255
# hr_zone:6
# segmentid:-1
# hr:15
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-05-25
# crashid:367416342017
# hdr:None
# a:1
# c:0
# b:0
# hr_txt:15:00-18:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:1
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36758118
# inj:1
# id:33
# danger_cnt:None
# pd_act:
# severity:B
# fatal_hdr:None
# tme:Jun  8 2017 11:55AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:11
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-06-08
# crashid:367581182017
# hdr:None
# a:0
# c:0
# b:1
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:BI
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36781736
# inj:1
# id:34
# danger_cnt:None
# pd_act:
# severity:None
# fatal_hdr:None
# tme:Jun 21 2017 12:15AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:1
# segmentid:-1
# hr:0
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-06-21
# crashid:367817362017
# hdr:None
# a:0
# c:0
# b:0
# hr_txt:00:00-03:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:1
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36784868
# inj:1
# id:35
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Jun 27 2017 11:45AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:-1
# hr:11
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-06-27
# crashid:367848682017
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36837649
# inj:2
# id:36
# danger_cnt:None
# pd_act:
# severity:CC
# fatal_hdr:None
# tme:Jul  3 2017  7:15AM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:3
# segmentid:-1
# hr:7
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-07-03
# crashid:368376492017
# hdr:None
# a:0
# c:2
# b:0
# hr_txt:06:00-09:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36843766
# inj:1
# id:37
# danger_cnt:None
# pd_act:
# severity:C
# fatal_hdr:None
# tme:Aug  9 2017  9:50PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:8
# segmentid:-1
# hr:21
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-08-09
# crashid:368437662017
# hdr:None
# a:0
# c:1
# b:0
# hr_txt:21:00-24:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:36996137
# inj:0
# id:38
# danger_cnt:None
# pd_act:
# severity:None
# fatal_hdr:None
# tme:Nov 17 2017  6:00PM
# ksi_tot:None
# st_x:997183
# ksi:0
# inj_per:None
# st_y:187255
# hr_zone:7
# segmentid:-1
# hr:18
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2017
# ac_date:2017-11-17
# crashid:369961372017
# hdr:None
# a:0
# c:0
# b:0
# hr_txt:18:00-21:00
# fatal_veh_typ:None
# f:0
# mm:None
# age:None
# si:0
# f_all:0
# u:0
# mode:MVO
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# shp_len:0.0
# col_typ:
# boro:3
# f_tot:None
# mft:None
# case_num:5150011
# inj:0
# id:39
# danger_cnt:3
# pd_act:
# severity:
# fatal_hdr:None
# tme:11:28:00.0000000
# ksi_tot:None
# st_x:997183
# ksi:1
# inj_per:None
# st_y:187255
# hr_zone:4
# segmentid:None
# hr:11
# inj_tot:None
# nodeid:18976
# masterid:18976
# boro_msg:None
# cor_ksi_fewer_percentile:None
# tot_mile:None
# yr:2015
# ac_date:2015-04-18
# crashid:4565
# hdr:None
# a:0
# c:0
# b:0
# hr_txt:09:00-12:00
# fatal_veh_typ:CAR\VAN\PICKUP | PEDESTRIAN |
# f:1
# mm:None
# age:61
# si:0
# f_all:1
# u:0
# mode:PD
# cor_ksi_msg:None
# danger_str:None
# fld:ALL
# ------
# 6521

# %%
db.connect()
# Out:
# Database connection (PG) to sip on dotpgsql01 - user: soge
# Connection established 2020-09-11 15:26:05

# %%
sip_projects = db.dfquery("""   SELECT *
                                FROM sip_projects
                                WHERE left(end_date::varchar,4) = '2019'""")

# %%
def GetAdvCrashHistory():
    _req_id = 0;
    _url = _api_url + "AdvQuery/GetAdvCrashHistory";
    _data = {
        "req_id":0,
        "sip_id ": "866",
        "prj_title": "Advanced Query for SIP Project 866",
        "sel_type": "NODE",
        "nd_seg_ids": "18976",
        "from": "01/01/2010",
        "to": "12/31/2018",
        "usr_id": "Seth",
        "crash_type": "",
        "severity":"",
        "src": "NYS"
    }
    r = requests.post(_url, data=_data, headers=_api_hdr)
    if(r.ok):

        jData = json.loads(r.content)
        print("Output contains {0} properties".format(len(jData)))
        print("\n")
        _req_id = jData["req_id"]
        print("req_id: " + str(jData["req_id"]))
    else:
        print("Error: " + r.reason + ', ' + r.text)

    return _req_id
#--------------------------------------------------
# AdvCrashHistory: Get UPDATE of an old Request
#--------------------------------------------------
def GetAdvCrashHistoryUpdate(req_id):
    _url = _api_url + "AdvQuery/GetAdvCrashHistory";
    _data = {
            "req_id": str(req_id),
            "action": "UPDATE"
        }
    r = requests.post(_url, data=_data, headers=_api_hdr)
    if(r.ok):
        jData = json.loads(r.content)
        print("Output contains {0} properties".format(len(jData)))
        print("\n")
        _req_id = jData["req_id"]
    else:
        print("Error\n")
        print(r.reason + ', ' + r.text)

    return _req_id
#------------------------------------
# Get Excel file, req_id is needed
#------------------------------------
def GetAdvCrashHistoryExcel(req_id):
    _url = _api_url + "AdvQuery/GetAdvCrashHistoryExcel?req_id=" + str(req_id) + "&typ=CSV";
    r = requests.get(_url, headers=_api_hdr)
    if(r.ok):

        os.chdir(".")
        file = os.getcwd() + "\\" +  str(req_id) + ".csv"
        print("Excel CSV File " , file)
        f = open(file, "wb")
        bary = bytearray(r.content)
        f.write(bary)
        f.close()
        os.system(r'start ' + file)
    else:
        print("Error: " + r.reason + ', ' + r.text)

# %%
#-------------------
# main program.....
#-------------------
print("#==========================================")
print("# SDV2 Advanced Query Sample python script")
print("# Exec GetAdvCrashHistory, get req_id ")
print("# Use the req_id to get the EXCEL output ")
print("#==========================================")
req_id = 0
print("Executing.... Advanced Query Crash History")
#-----------------------------------------
# Get Advanced CrashHistory: NEW REQUEST
#-----------------------------------------
req_id = GetAdvCrashHistory()
if req_id > 0:
    print("Fetching CSV Export file for Advanced Crash History Request ID:" + str(req_id))
    GetAdvCrashHistoryExcel(req_id);
#------------------------------------------
# Get Advanced CrashHistory: UPDATE REQUEST
#------------------------------------------
if req_id > 0:
    print("Get updated Advanced Crash History for Request ID:" + str(req_id))
    GetAdvCrashHistoryUpdate(req_id);
    print("Fetching CSV Export file for Advanced Crash History Request ID:" + str(req_id))
    GetAdvCrashHistoryExcel(req_id);
print("Completed...")
# Out:
# #==========================================
# # SDV2 Advanced Query Sample python script
# # Exec GetAdvCrashHistory, get req_id
# # Use the req_id to get the EXCEL output
# #==========================================
# Executing.... Advanced Query Crash History
# Output contains 9 properties
#
#
# req_id: 6490
# Fetching CSV Export file for Advanced Crash History Request ID:6490
# ('Excel CSV File ', 'E:\\RIS\\Staff Folders\\Samuel\\Requests\\SH\\SIP SDV API\\6490.csv')
